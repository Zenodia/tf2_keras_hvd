# %%
# !nvidia-smi
# Out:
# Mon Oct  5 10:06:20 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.51.06    Driver Version: 450.51.06    CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  On   | 00000000:0A:00.0 Off |                    0 |
# | N/A   36C    P0    44W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.3.0'

# %%
# !horovodrun -np 4 python fmnist_multigpus.py --epochs 10 --batch-size 512
# Out:
# 2020-10-05 10:06:23.437182: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# [1,0]<stderr>:WARNING:tensorflow:From fmnist_multigpus.py:273: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# [1,0]<stderr>:Instructions for updating:
# [1,0]<stderr>:Please use Model.fit, which supports generators.
# [1,3]<stderr>:WARNING:tensorflow:From fmnist_multigpus.py:273: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# [1,3]<stderr>:Instructions for updating:
# [1,3]<stderr>:Please use Model.fit, which supports generators.
# [1,2]<stderr>:WARNING:tensorflow:From fmnist_multigpus.py:273: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# [1,2]<stderr>:Instructions for updating:
# ...

# %%
# !horovodrun -np 4 python fmnist_multigpus_suppress_stderr.py --epochs 3 --batch-size 512
# Out:
# 2020-10-05 10:22:58.133125: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# [1,0]<stderr>:2020-10-05 10:23:00.054764: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# [1,1]<stderr>:2020-10-05 10:23:00.087141: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# [1,2]<stderr>:2020-10-05 10:23:00.087141: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# [1,3]<stderr>:2020-10-05 10:23:00.101799: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# [1,0]<stderr>:2020-10-05 10:23:01.380401: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# ...
